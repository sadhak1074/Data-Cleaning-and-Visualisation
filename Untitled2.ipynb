# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("superstore_final_dataset.csv")

# %%
data.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.shape
# Out:
# (9800, 18)

# %%
data.isnull().sum()
# Out:
# Row_ID            0
# Order_ID          0
# Order_Date        0
# Ship_Date         0
# Ship_Mode         0
# Customer_ID       0
# Customer_Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal_Code      11
# Region            0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Sales             0
# dtype: int64

# %%
duplicates = data[data.duplicated(subset=['Order_ID'])]
print(duplicates.sum())
# Out:
# Row_ID                                                    23619238
# Order_ID         CA-2017-152156US-2016-108966CA-2015-115812CA-2...
# Order_Date       08/11/201711/10/201609/06/201509/06/201509/06/...
# Ship_Date        11/11/201718/10/201614/06/201514/06/201514/06/...
# Ship_Mode        Second ClassStandard ClassStandard ClassStanda...
# Customer_ID      CG-12520SO-20335BH-11710BH-11710BH-11710BH-117...
# Customer_Name    Claire GuteSean O DonnelBrosina HoffmanBrosina...
# Segment          ConsumerConsumerConsumerConsumerConsumerConsum...
# Country          United StatesUnited StatesUnited StatesUnited ...
# City             HendersonFort LauderdaleLos AngelesLos Angeles...
# State            KentuckyFloridaCaliforniaCaliforniaCaliforniaC...
# Postal_Code                                            268062977.0
# Region           SouthSouthWestWestWestWestWestWestCentralWestW...
# Product_ID       FUR-CH-10000454OFF-ST-10000760OFF-AR-10002833T...
# ...

# %%
new_data = data.drop('Postal_Code', axis=1)
new_data.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df = new_data.drop_duplicates(subset=['Customer_ID'])
print(df)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5          6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 12        13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# ...      ...             ...         ...         ...             ...
# 8666    8667  CA-2017-163951  30/12/2017  02/01/2018     First Class
# 9209    9210  CA-2018-142776  11/12/2018  14/12/2018    Second Class
# 9399    9400  CA-2017-103128  11/11/2017  15/11/2017  Standard Class
# 9441    9442  CA-2015-165477  29/12/2015  31/12/2015    Second Class
# 9558    9559  CA-2017-129280  03/05/2017  05/05/2017     First Class
#
#      Customer_ID      Customer_Name      Segment        Country  \
# 0       CG-12520        Claire Gute     Consumer  United States
# ...

# %%
df.head(793)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5          6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 12        13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# ...      ...             ...         ...         ...             ...
# 8666    8667  CA-2017-163951  30/12/2017  02/01/2018     First Class
# 9209    9210  CA-2018-142776  11/12/2018  14/12/2018    Second Class
# 9399    9400  CA-2017-103128  11/11/2017  15/11/2017  Standard Class
# 9441    9442  CA-2015-165477  29/12/2015  31/12/2015    Second Class
# 9558    9559  CA-2017-129280  03/05/2017  05/05/2017     First Class
#
#      Customer_ID      Customer_Name      Segment        Country  \
# 0       CG-12520        Claire Gute     Consumer  United States
# ...

# %%
df.to_csv('super_store.csv', index=False)

# %%
s_store=pd.read_csv("super_store.csv")

# %%
print(s_store.isna().any())
# Out:
# Row_ID           False
# Order_ID         False
# Order_Date       False
# Ship_Date        False
# Ship_Mode        False
# Customer_ID      False
# Customer_Name    False
# Segment          False
# Country          False
# City             False
# State            False
# Region           False
# Product_ID       False
# Category         False
# Sub_Category     False
# Product_Name     False
# Sales            False
# dtype: bool

# %%
s_store.describe()
# Out:
#             Row_ID         Sales
# count   793.000000    793.000000
# mean   1619.607818    212.423523
# std    1603.444372    614.344998
# min       1.000000      1.080000
# 25%     496.000000     15.552000
# 50%    1147.000000     48.712000
# 75%    2248.000000    176.800000
# max    9559.000000  11199.968000
